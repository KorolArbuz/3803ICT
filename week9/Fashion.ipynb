# %% [markdown]
# # Image Classification by MLP - Fashion MNIST

# %% [markdown]
# In this exercise, we will try to use a neural network on a simple classification task: classifying images of clothes into 10 classes.

# %% [markdown]
# We will first download the data:

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# Out:
# 2.6.0+cu126 True
# gcc (MinGW.org GCC-6.3.0-1) 6.3.0
# Copyright (C) 2016 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
import tensorflow as tf
print(tf.__version__)
from tensorflow.keras.datasets import fashion_mnist

#TODO: load dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

#TODO: Resample the dataset if needed
#X_train = ...
#y_train = ...
#X_test = ...
#y_test = ...

X_train.shape
# Out:
# 2.13.1
# (60000, 28, 28)

# %% [markdown]
# This dataset contains 10 classes:
# * 0:	T-shirt/top
# * 1:	Trouser
# * 2:	Pullover
# * 3:	Dress
# * 4:	Coat
# * 5:	Sandal
# * 6:	Shirt
# * 7:	Sneaker
# * 8:	Bag
# * 9:	Ankle boot

# %% [markdown]
# Now begin by exploring the data. Try to display some images with the associated label.

# %%
# TODO: Explore the data, display some input images
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

label_class = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# np.random.seed(0)
idx = np.random.randint(X_train.shape[0])
plt.imshow(X_train[idx], cmap = "gray_r")
plt.title(label_class[y_train[idx]])
plt.show()

# %% [markdown]
# **Before going further**: what methods could you use to perform such a classification task?

# %% [markdown]
# ---

# %% [markdown]
# The first method you will try is using neural networks. First step is the data preparation: data rescaling, label preparation.
#
# Hint: you can use the Keras function `to_categorical`

# %%
# TODO: Make the data preparation
from tensorflow.keras.utils import to_categorical

y_train_cat = to_categorical(y_train, num_classes=10).astype(np.float32) 
y_test_cat = to_categorical(y_test, num_classes=10).astype(np.float32)   

X_train_norm = (X_train / 255.0).astype(np.float32)  
X_test_norm = (X_test / 255.0).astype(np.float32)    

X_train_norm = X_train_norm.reshape(X_train_norm.shape[0], np.prod(X_train_norm.shape[1:]))
X_test_norm = X_test_norm.reshape(X_test_norm.shape[0], np.prod(X_test_norm.shape[1:]))
print(np.shape(X_train_norm))
# Out:
# (60000, 784)

# %% [markdown]
# Next step: model building with Keras. Build your neural network architecture. At first, I would recommend a light architecture: no more than 2 hidden layers, with about 10 units per layer. Put that model into a function, so that you can reuse it later.

# %%
# TODO: Build your model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def my_model(input_dim):
    # Create the Sequential object
    model = Sequential()

    # Add 2 dense layers with 10 neurons each using sigmoid or relu activation
    model.add(Dense(10, input_dim = input_dim, activation = "sigmoid"))
    model.add(Dense(10, activation = "sigmoid"))
    
    # Add the output layer with one unit: the predicted result
    model.add(Dense(10, activation='softmax'))
    
    return model

my_model(X_train_norm.shape[1]).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                7850
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 8070 (31.52 KB)
# Trainable params: 8070 (31.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now compile and fit your model on your training data. Since this is a multiclass classification, the loss is not `binary_crossentropy` anymore, but `categorical_crossentropy`.

# %%
import os

#https://stackoverflow.com/questions/53014306/error-15-initializing-libiomp5-dylib-but-found-libiomp5-dylib-already-initial
# os.environ['KMP_DUPLICATE_LIB_OK']='True' 

# TODO: Compile and fit your model
model = my_model(X_train_norm.shape[1])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train_norm, y_train_cat, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 1s 1ms/step - loss: 1.9080 - accuracy: 0.3915
# Epoch 2/100
# 469/469 [==============================] - 1s 1ms/step - loss: 1.3309 - accuracy: 0.6532
# Epoch 3/100
# 469/469 [==============================] - 1s 1ms/step - loss: 1.0195 - accuracy: 0.7401
# Epoch 4/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.8274 - accuracy: 0.7881
# Epoch 5/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.6868 - accuracy: 0.8146
# Epoch 6/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.5936 - accuracy: 0.8285
# Epoch 7/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.8381
# Epoch 8/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4947 - accuracy: 0.8444
# Epoch 9/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4665 - accuracy: 0.8501
# Epoch 10/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4469 - accuracy: 0.8529
# Epoch 11/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4318 - accuracy: 0.8565
# Epoch 12/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4208 - accuracy: 0.8589
# Epoch 13/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4119 - accuracy: 0.8616
# Epoch 14/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.4053 - accuracy: 0.8630
# Epoch 15/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3994 - accuracy: 0.8644
# Epoch 16/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3942 - accuracy: 0.8659
# Epoch 17/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3893 - accuracy: 0.8677
# Epoch 18/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3853 - accuracy: 0.8686
# Epoch 19/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3816 - accuracy: 0.8698
# Epoch 20/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3791 - accuracy: 0.8704
# Epoch 21/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3749 - accuracy: 0.8707
# Epoch 22/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3728 - accuracy: 0.8714
# Epoch 23/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3703 - accuracy: 0.8726
# Epoch 24/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3684 - accuracy: 0.8729
# Epoch 25/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3657 - accuracy: 0.8751
# Epoch 26/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3628 - accuracy: 0.8752
# Epoch 27/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3609 - accuracy: 0.8755
# Epoch 28/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3588 - accuracy: 0.8758
# Epoch 29/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3573 - accuracy: 0.8761
# Epoch 30/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3560 - accuracy: 0.8765
# Epoch 31/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3544 - accuracy: 0.8768
# Epoch 32/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3517 - accuracy: 0.8780
# Epoch 33/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3495 - accuracy: 0.8789
# Epoch 34/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3493 - accuracy: 0.8783
# Epoch 35/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3486 - accuracy: 0.8789
# Epoch 36/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3463 - accuracy: 0.8791
# Epoch 37/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3448 - accuracy: 0.8798
# Epoch 38/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3442 - accuracy: 0.8807
# Epoch 39/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3430 - accuracy: 0.8800
# Epoch 40/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3409 - accuracy: 0.8813
# Epoch 41/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3396 - accuracy: 0.8817
# Epoch 42/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3402 - accuracy: 0.8818
# Epoch 43/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3382 - accuracy: 0.8823
# Epoch 44/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3368 - accuracy: 0.8831
# Epoch 45/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3361 - accuracy: 0.8830
# Epoch 46/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3351 - accuracy: 0.8827
# Epoch 47/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3344 - accuracy: 0.8837
# Epoch 48/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3332 - accuracy: 0.8834
# Epoch 49/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3316 - accuracy: 0.8848
# Epoch 50/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3310 - accuracy: 0.8845
# Epoch 51/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3293 - accuracy: 0.8852
# Epoch 52/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3290 - accuracy: 0.8844
# Epoch 53/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3292 - accuracy: 0.8844
# Epoch 54/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3280 - accuracy: 0.8849
# Epoch 55/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3271 - accuracy: 0.8868
# Epoch 56/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3259 - accuracy: 0.8859
# Epoch 57/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3261 - accuracy: 0.8863
# Epoch 58/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3241 - accuracy: 0.8869
# Epoch 59/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3241 - accuracy: 0.8868
# Epoch 60/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3233 - accuracy: 0.8864
# Epoch 61/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3233 - accuracy: 0.8866
# Epoch 62/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3241 - accuracy: 0.8858
# Epoch 63/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3214 - accuracy: 0.8877
# Epoch 64/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3200 - accuracy: 0.8877
# Epoch 65/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3198 - accuracy: 0.8885
# Epoch 66/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3203 - accuracy: 0.8871
# Epoch 67/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3192 - accuracy: 0.8884
# Epoch 68/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3191 - accuracy: 0.8885
# Epoch 69/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3184 - accuracy: 0.8887
# Epoch 70/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3173 - accuracy: 0.8883
# Epoch 71/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3174 - accuracy: 0.8892
# Epoch 72/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3162 - accuracy: 0.8888
# Epoch 73/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3161 - accuracy: 0.8890
# Epoch 74/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3155 - accuracy: 0.8890
# Epoch 75/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3145 - accuracy: 0.8904
# Epoch 76/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3138 - accuracy: 0.8893
# Epoch 77/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3131 - accuracy: 0.8906
# Epoch 78/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3132 - accuracy: 0.8903
# Epoch 79/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3132 - accuracy: 0.8904
# Epoch 80/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3118 - accuracy: 0.8911
# Epoch 81/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3128 - accuracy: 0.8904
# Epoch 82/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3119 - accuracy: 0.8909
# Epoch 83/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3106 - accuracy: 0.8913
# Epoch 84/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3106 - accuracy: 0.8909
# Epoch 85/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3094 - accuracy: 0.8916
# Epoch 86/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3094 - accuracy: 0.8915
# Epoch 87/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3089 - accuracy: 0.8911
# Epoch 88/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3097 - accuracy: 0.8904
# Epoch 89/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3069 - accuracy: 0.8928
# Epoch 90/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3078 - accuracy: 0.8919
# Epoch 91/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3068 - accuracy: 0.8930
# Epoch 92/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3070 - accuracy: 0.8916
# Epoch 93/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3072 - accuracy: 0.8924
# Epoch 94/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3050 - accuracy: 0.8927
# Epoch 95/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3063 - accuracy: 0.8929
# Epoch 96/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3062 - accuracy: 0.8921
# Epoch 97/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3038 - accuracy: 0.8925
# Epoch 98/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3038 - accuracy: 0.8928
# Epoch 99/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3039 - accuracy: 0.8926
# Epoch 100/100
# 469/469 [==============================] - 1s 1ms/step - loss: 0.3048 - accuracy: 0.8923

# %% [markdown]
# Once your model has been trained, compute the accuracy (and other metrics if you want) on the train and test dataset.
#
# Be careful, Keras returns softmax output (so an array of 10 values between 0 and 1, for which the sum is equal to 1). To compute correctly the accuracy, you have to convert that array into a categorical array with zeros and a 1.

# %%
# TODO: Compute the accuracy of your model
print('accuracy on train with NN:', model.evaluate(X_train_norm, y_train_cat, verbose=0)[1])
print('accuracy on test with NN:', model.evaluate(X_test_norm, y_test_cat, verbose=0)[1])
# Out:
# accuracy on train with NN: 0.8945666551589966
# accuracy on test with NN: 0.85589998960495

# %% [markdown]
# What do you think of those results? Can you improve it by changing the number of layers? Of units per layer? The number of epochs? The activation functions?
#
# You should try!

# %% [markdown]
# ---

# %% [markdown]
# In order to compare your results with more traditional machine learning methods, you will do this work with another method: a PCA followed by a classification model (of your choice). Of course, you can perform hyperparameter optimization using a gridsearch on that model!
#
# Fit your model and display the performances.

# %%
# TODO: Redo the classification with PCA and classification model
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9)

pca.fit(X_train_norm)
X_train_pca = pca.transform(X_train_norm)
X_test_pca = pca.transform(X_test_norm)

# %%
# TODO: use any classifier you want
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(X_train_pca, y_train)

print('score with RF on train', rf.score(X_train_pca, y_train))
print('score with RF on train', rf.score(X_test_pca, y_test))
# Out:
# score with RF on train 1.0
# score with RF on train 0.8598

# %% [markdown]
# Are the performances different? Can you explain why?

# %% [markdown]
# If you still have time, you could try to use scikit-learn's `Pipeline` to perform the hyperparameter optimization jointly on the PCA and the classification model. This might improve your performances.
