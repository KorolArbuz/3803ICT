# %% [markdown]
# # Image Classification with CNN - LeNet5 architecture

# %% [markdown]
# In this exercise, we will apply the LeNet5 algorithm to the Fashion MNIST dataset and improve your performances.

# %% [markdown]
# We will first download the data:

# %%
# TODO: Load the dataset
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# # # If your computer is slow, try to use a subset of data, e.g.
# X_train = X_train[:10000]
# y_train = y_train[:10000]
# X_test = X_test[:2000]
# y_test = y_test[:2000]
X_train.shape
# Out:
# Using device: cuda
# (60000, 28, 28)

# %% [markdown]
# As you already know, this dataset contains 10 classes:
# * 0:	T-shirt/top
# * 1:	Trouser
# * 2:	Pullover
# * 3:	Dress
# * 4:	Coat
# * 5:	Sandal
# * 6:	Shirt
# * 7:	Sneaker
# * 8:	Bag
# * 9:	Ankle boot

# %% [markdown]
# You can have a look at some images if needed, even if you already know them.

# %%
# TODO: Explore the data, display some input images
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

label_class = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

idx = np.random.randint(X_train.shape[0])

plt.imshow(X_train[idx], cmap = "gray_r")
plt.title(label_class[y_train[idx]])
plt.show()

# %% [markdown]
# Make the data preparation and preprocessing: scale and reshape the data, put the labels to the good shape.

# %%
# TODO: Make the data preparation
from tensorflow.keras.utils import to_categorical

y_train_cat = to_categorical(y_train, num_classes=10).astype(np.float32) 
y_test_cat = to_categorical(y_test, num_classes=10).astype(np.float32)   

X_train_norm = (X_train / 255.0).astype(np.float32)  
X_test_norm = (X_test / 255.0).astype(np.float32)    


X_train_norm = X_train_norm.reshape(X_train_norm.shape[0], 28, 28, 1)
X_test_norm = X_test_norm.reshape(X_test_norm.shape[0], 28, 28, 1)

X_train_norm.shape #Should be (60000, 28, 28, 1)
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# Now build the LeNet5 architecture. You can reuse the one of the course, or try to build it by yourself.
#
# The architecture is the following:
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1WteTU2FPIVMkBKmMxGpFm5OjsX-szTbB">
# </p>

# %%
# TODO: Build your model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Conv2D, Flatten, Dense


def lenet5():
    
    model = Sequential()

    # Layer C1
    model.add(Conv2D(filters=6, name='C1', kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
    # Layer S2
    model.add(MaxPooling2D(pool_size=(2, 2), name='S2'))
    # Layer C3
    model.add(Conv2D(filters=16, name='C3', kernel_size=(3, 3), activation='relu'))
    # Layer S4
    model.add(MaxPooling2D(pool_size=(2, 2), name='S4'))
    # Before going into layer C5, we flatten our units
    model.add(Flatten())
    # Layer C5
    model.add(Dense(120, activation='relu', name='S5'))
    # Layer F6
    model.add(Dense(84, activation='relu', name='F6'))
    # Output layer
    model.add(Dense(units=10, activation = 'softmax'))
    
    return model

lenet5().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  C1 (Conv2D)                 (None, 26, 26, 6)         60
#
#  S2 (MaxPooling2D)           (None, 13, 13, 6)         0
#
#  C3 (Conv2D)                 (None, 11, 11, 16)        880
#
#  S4 (MaxPooling2D)           (None, 5, 5, 16)          0
#
#  flatten (Flatten)           (None, 400)               0
#
#  S5 (Dense)                  (None, 120)               48120
#
#  F6 (Dense)                  (None, 84)                10164
#
#  dense (Dense)               (None, 10)                850
#
# =================================================================
# Total params: 60074 (234.66 KB)
# Trainable params: 60074 (234.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now compile and fit your model on your training data. Since this is a multiclass classification, the loss is not `binary_crossentropy` anymore, but `categorical_crossentropy`.

# %%
# TODO: Compile and fit your model
import os

# os.environ['KMP_DUPLICATE_LIB_OK']='True' #https://stackoverflow.com/questions/53014306/error-15-initializing-libiomp5-dylib-but-found-libiomp5-dylib-already-initial


from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import TensorBoard

model = lenet5()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define now our callbacks
# callbacks = [EarlyStopping(monitor='val_loss', patience=10), TensorBoard(log_dir='./keras-logs', histogram_freq=0, write_graph=True, write_images=True)]
callbacks = [EarlyStopping(monitor='val_loss', patience=10)]

# Finally fit the model
model.fit(x=X_train_norm, y=y_train_cat, validation_data=(X_test_norm, y_test_cat), epochs=100, batch_size=2048, callbacks=callbacks)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 7s 187ms/step - loss: 1.7063 - accuracy: 0.5084 - val_loss: 0.9425 - val_accuracy: 0.6635
# Epoch 2/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.7563 - accuracy: 0.7249 - val_loss: 0.6633 - val_accuracy: 0.7543
# Epoch 3/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.5953 - accuracy: 0.7771 - val_loss: 0.5785 - val_accuracy: 0.7804
# Epoch 4/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.5336 - accuracy: 0.7985 - val_loss: 0.5224 - val_accuracy: 0.8050
# Epoch 5/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.4926 - accuracy: 0.8170 - val_loss: 0.4999 - val_accuracy: 0.8157
# Epoch 6/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.4689 - accuracy: 0.8295 - val_loss: 0.4774 - val_accuracy: 0.8286
# Epoch 7/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.4480 - accuracy: 0.8395 - val_loss: 0.4685 - val_accuracy: 0.8296
# Epoch 8/100
# 30/30 [==============================] - 5s 183ms/step - loss: 0.4344 - accuracy: 0.8438 - val_loss: 0.4583 - val_accuracy: 0.8311
# Epoch 9/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.4193 - accuracy: 0.8507 - val_loss: 0.4487 - val_accuracy: 0.8388
# Epoch 10/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.4125 - accuracy: 0.8524 - val_loss: 0.4259 - val_accuracy: 0.8457
# Epoch 11/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.3953 - accuracy: 0.8597 - val_loss: 0.4147 - val_accuracy: 0.8514
# Epoch 12/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3892 - accuracy: 0.8626 - val_loss: 0.4098 - val_accuracy: 0.8519
# Epoch 13/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.3794 - accuracy: 0.8658 - val_loss: 0.4066 - val_accuracy: 0.8543
# Epoch 14/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.3742 - accuracy: 0.8673 - val_loss: 0.4017 - val_accuracy: 0.8571
# Epoch 15/100
# 30/30 [==============================] - 5s 175ms/step - loss: 0.3714 - accuracy: 0.8684 - val_loss: 0.4114 - val_accuracy: 0.8533
# Epoch 16/100
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3700 - accuracy: 0.8676 - val_loss: 0.3905 - val_accuracy: 0.8619
# Epoch 17/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.3593 - accuracy: 0.8726 - val_loss: 0.3901 - val_accuracy: 0.8631
# Epoch 18/100
# 30/30 [==============================] - 5s 169ms/step - loss: 0.3566 - accuracy: 0.8725 - val_loss: 0.3964 - val_accuracy: 0.8576
# Epoch 19/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3504 - accuracy: 0.8759 - val_loss: 0.3754 - val_accuracy: 0.8680
# Epoch 20/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3479 - accuracy: 0.8747 - val_loss: 0.3772 - val_accuracy: 0.8649
# Epoch 21/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.3427 - accuracy: 0.8783 - val_loss: 0.3679 - val_accuracy: 0.8703
# Epoch 22/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.3398 - accuracy: 0.8778 - val_loss: 0.3797 - val_accuracy: 0.8619
# Epoch 23/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.3376 - accuracy: 0.8784 - val_loss: 0.3654 - val_accuracy: 0.8708
# Epoch 24/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.3341 - accuracy: 0.8792 - val_loss: 0.3585 - val_accuracy: 0.8719
# Epoch 25/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3259 - accuracy: 0.8836 - val_loss: 0.3634 - val_accuracy: 0.8704
# Epoch 26/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.3260 - accuracy: 0.8822 - val_loss: 0.3569 - val_accuracy: 0.8728
# Epoch 27/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.3219 - accuracy: 0.8848 - val_loss: 0.3566 - val_accuracy: 0.8723
# Epoch 28/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3181 - accuracy: 0.8860 - val_loss: 0.3570 - val_accuracy: 0.8730
# Epoch 29/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.3139 - accuracy: 0.8871 - val_loss: 0.3479 - val_accuracy: 0.8755
# Epoch 30/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.3107 - accuracy: 0.8885 - val_loss: 0.3458 - val_accuracy: 0.8753
# Epoch 31/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.3081 - accuracy: 0.8892 - val_loss: 0.3416 - val_accuracy: 0.8778
# Epoch 32/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.3084 - accuracy: 0.8881 - val_loss: 0.3435 - val_accuracy: 0.8770
# Epoch 33/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3050 - accuracy: 0.8896 - val_loss: 0.3417 - val_accuracy: 0.8785
# Epoch 34/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.3018 - accuracy: 0.8910 - val_loss: 0.3470 - val_accuracy: 0.8741
# Epoch 35/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.3071 - accuracy: 0.8884 - val_loss: 0.3502 - val_accuracy: 0.8752
# Epoch 36/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2983 - accuracy: 0.8921 - val_loss: 0.3336 - val_accuracy: 0.8800
# Epoch 37/100
# 30/30 [==============================] - 5s 169ms/step - loss: 0.2931 - accuracy: 0.8936 - val_loss: 0.3326 - val_accuracy: 0.8804
# Epoch 38/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2913 - accuracy: 0.8945 - val_loss: 0.3363 - val_accuracy: 0.8771
# Epoch 39/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2924 - accuracy: 0.8936 - val_loss: 0.3278 - val_accuracy: 0.8807
# Epoch 40/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2877 - accuracy: 0.8959 - val_loss: 0.3290 - val_accuracy: 0.8809
# Epoch 41/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2887 - accuracy: 0.8953 - val_loss: 0.3269 - val_accuracy: 0.8826
# Epoch 42/100
# 30/30 [==============================] - 5s 180ms/step - loss: 0.2858 - accuracy: 0.8965 - val_loss: 0.3369 - val_accuracy: 0.8775
# Epoch 43/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2822 - accuracy: 0.8977 - val_loss: 0.3257 - val_accuracy: 0.8826
# Epoch 44/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2805 - accuracy: 0.8980 - val_loss: 0.3202 - val_accuracy: 0.8860
# Epoch 45/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2777 - accuracy: 0.8994 - val_loss: 0.3194 - val_accuracy: 0.8845
# Epoch 46/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2771 - accuracy: 0.8996 - val_loss: 0.3176 - val_accuracy: 0.8850
# Epoch 47/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2721 - accuracy: 0.9016 - val_loss: 0.3227 - val_accuracy: 0.8839
# Epoch 48/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2720 - accuracy: 0.9014 - val_loss: 0.3311 - val_accuracy: 0.8807
# Epoch 49/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2760 - accuracy: 0.9002 - val_loss: 0.3192 - val_accuracy: 0.8852
# Epoch 50/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2686 - accuracy: 0.9023 - val_loss: 0.3328 - val_accuracy: 0.8788
# Epoch 51/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2728 - accuracy: 0.8997 - val_loss: 0.3151 - val_accuracy: 0.8858
# Epoch 52/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2641 - accuracy: 0.9041 - val_loss: 0.3155 - val_accuracy: 0.8851
# Epoch 53/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2695 - accuracy: 0.9020 - val_loss: 0.3170 - val_accuracy: 0.8877
# Epoch 54/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2657 - accuracy: 0.9041 - val_loss: 0.3199 - val_accuracy: 0.8850
# Epoch 55/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2615 - accuracy: 0.9056 - val_loss: 0.3115 - val_accuracy: 0.8878
# Epoch 56/100
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2578 - accuracy: 0.9070 - val_loss: 0.3227 - val_accuracy: 0.8861
# Epoch 57/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2575 - accuracy: 0.9069 - val_loss: 0.3141 - val_accuracy: 0.8880
# Epoch 58/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2596 - accuracy: 0.9056 - val_loss: 0.3270 - val_accuracy: 0.8818
# Epoch 59/100
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2617 - accuracy: 0.9051 - val_loss: 0.3115 - val_accuracy: 0.8882
# Epoch 60/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2517 - accuracy: 0.9095 - val_loss: 0.3205 - val_accuracy: 0.8877
# Epoch 61/100
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2524 - accuracy: 0.9085 - val_loss: 0.3057 - val_accuracy: 0.8899
# Epoch 62/100
# 30/30 [==============================] - 5s 179ms/step - loss: 0.2494 - accuracy: 0.9101 - val_loss: 0.3091 - val_accuracy: 0.8907
# Epoch 63/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2471 - accuracy: 0.9108 - val_loss: 0.3037 - val_accuracy: 0.8934
# Epoch 64/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2462 - accuracy: 0.9104 - val_loss: 0.3126 - val_accuracy: 0.8879
# Epoch 65/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2455 - accuracy: 0.9117 - val_loss: 0.3049 - val_accuracy: 0.8930
# Epoch 66/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.2439 - accuracy: 0.9115 - val_loss: 0.3050 - val_accuracy: 0.8917
# Epoch 67/100
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2433 - accuracy: 0.9116 - val_loss: 0.3064 - val_accuracy: 0.8902
# Epoch 68/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2423 - accuracy: 0.9118 - val_loss: 0.3098 - val_accuracy: 0.8882
# Epoch 69/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2382 - accuracy: 0.9140 - val_loss: 0.3042 - val_accuracy: 0.8933
# Epoch 70/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2372 - accuracy: 0.9141 - val_loss: 0.2989 - val_accuracy: 0.8933
# Epoch 71/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2380 - accuracy: 0.9142 - val_loss: 0.3128 - val_accuracy: 0.8880
# Epoch 72/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2375 - accuracy: 0.9140 - val_loss: 0.2980 - val_accuracy: 0.8946
# Epoch 73/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2339 - accuracy: 0.9156 - val_loss: 0.3032 - val_accuracy: 0.8926
# Epoch 74/100
# 30/30 [==============================] - 5s 177ms/step - loss: 0.2344 - accuracy: 0.9147 - val_loss: 0.3038 - val_accuracy: 0.8924
# Epoch 75/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2338 - accuracy: 0.9154 - val_loss: 0.3029 - val_accuracy: 0.8927
# Epoch 76/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2336 - accuracy: 0.9154 - val_loss: 0.3058 - val_accuracy: 0.8920
# Epoch 77/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2334 - accuracy: 0.9154 - val_loss: 0.3092 - val_accuracy: 0.8935
# Epoch 78/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2307 - accuracy: 0.9162 - val_loss: 0.2961 - val_accuracy: 0.8964
# Epoch 79/100
# 30/30 [==============================] - 5s 176ms/step - loss: 0.2239 - accuracy: 0.9194 - val_loss: 0.2978 - val_accuracy: 0.8968
# Epoch 80/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2242 - accuracy: 0.9187 - val_loss: 0.2998 - val_accuracy: 0.8950
# Epoch 81/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2288 - accuracy: 0.9172 - val_loss: 0.2993 - val_accuracy: 0.8933
# Epoch 82/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2262 - accuracy: 0.9180 - val_loss: 0.2958 - val_accuracy: 0.8959
# Epoch 83/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2211 - accuracy: 0.9197 - val_loss: 0.2987 - val_accuracy: 0.8942
# Epoch 84/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2203 - accuracy: 0.9205 - val_loss: 0.3021 - val_accuracy: 0.8933
# Epoch 85/100
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2213 - accuracy: 0.9198 - val_loss: 0.3000 - val_accuracy: 0.8953
# Epoch 86/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2215 - accuracy: 0.9195 - val_loss: 0.3042 - val_accuracy: 0.8948
# Epoch 87/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2185 - accuracy: 0.9201 - val_loss: 0.3158 - val_accuracy: 0.8889
# Epoch 88/100
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2218 - accuracy: 0.9200 - val_loss: 0.2984 - val_accuracy: 0.8968
# Epoch 89/100
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2169 - accuracy: 0.9218 - val_loss: 0.2972 - val_accuracy: 0.8965
# Epoch 90/100
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2135 - accuracy: 0.9222 - val_loss: 0.2958 - val_accuracy: 0.8988
# Epoch 91/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2141 - accuracy: 0.9226 - val_loss: 0.2999 - val_accuracy: 0.8954
# Epoch 92/100
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2124 - accuracy: 0.9228 - val_loss: 0.3018 - val_accuracy: 0.8933

# %% [markdown]
# Have a look at the tensorboard and see if it gives a deeper understanding of your model.

# %% [markdown]
# Compute then the accuracy of your model. Is it better than a regular MLP used before?

# %%
# TODO: Compute the accuracy of your model
from sklearn.metrics import accuracy_score

batch_size = 1024
y_pred_train = to_categorical(model.predict(X_train_norm, batch_size = batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm, batch_size = batch_size).argmax(axis=1), num_classes=10)

print('accuracy on train with NN:', accuracy_score(y_pred_train, y_train_cat))
print('accuracy on test with NN:', accuracy_score(y_pred_test, y_test_cat))
# Out:
# 59/59 [==============================] - 2s 33ms/step
# 10/10 [==============================] - 0s 33ms/step
# accuracy on train with NN: 0.9217666666666666
# accuracy on test with NN: 0.8933

# %% [markdown]
# We will now add image augmentation to improve our results, especially we will try to reduce overfitting this way.
#
# To do so, you can use `ImageDataGenerator` from Keras that makes all the work for you (including rescaling), with the following parameter:
# * `horizontal_flip=True`
#
# For more info about how the `ImageDataGenerator` works, you can check out [this article](https://www.pyimagesearch.com/2019/07/08/keras-imagedatagenerator-and-data-augmentation/).
#
# Begin by creating an object `ImageDataGenerator` with this parameter.

# %%
# TODO: Instantiate an ImageDataGenerator object
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(horizontal_flip=True)

# %% [markdown]
# Finally, you can train your model using this generator, with the method `fit_generator` of your model and the method `flow` of your `ImageDataGenerator`.

# %%
# TODO: train your model
batch_size = 1024
model.fit_generator(datagen.flow(X_train_norm, y_train_cat, batch_size=batch_size),
                    validation_data=(X_test_norm, y_test_cat), callbacks=callbacks,
                    steps_per_epoch=len(X_train_norm) / batch_size, epochs=100)
# Out:
# Epoch 1/100
# C:\Users\Denis\AppData\Local\Temp\ipykernel_29580\3271627435.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(datagen.flow(X_train_norm, y_train_cat, batch_size=batch_size),
# 58/58 [==============================] - 7s 107ms/step - loss: 0.4842 - accuracy: 0.8497 - val_loss: 0.3302 - val_accuracy: 0.8834
# Epoch 2/100
# 58/58 [==============================] - 6s 103ms/step - loss: 0.2986 - accuracy: 0.8929 - val_loss: 0.3088 - val_accuracy: 0.8912
# Epoch 3/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2815 - accuracy: 0.8978 - val_loss: 0.3010 - val_accuracy: 0.8930
# Epoch 4/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2733 - accuracy: 0.9008 - val_loss: 0.2981 - val_accuracy: 0.8944
# Epoch 5/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2654 - accuracy: 0.9047 - val_loss: 0.3005 - val_accuracy: 0.8946
# Epoch 6/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2622 - accuracy: 0.9047 - val_loss: 0.3008 - val_accuracy: 0.8951
# Epoch 7/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2584 - accuracy: 0.9061 - val_loss: 0.2960 - val_accuracy: 0.8948
# Epoch 8/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2542 - accuracy: 0.9088 - val_loss: 0.2931 - val_accuracy: 0.8985
# Epoch 9/100
# 58/58 [==============================] - 6s 103ms/step - loss: 0.2490 - accuracy: 0.9093 - val_loss: 0.2980 - val_accuracy: 0.8925
# Epoch 10/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2460 - accuracy: 0.9113 - val_loss: 0.2910 - val_accuracy: 0.8988
# Epoch 11/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2482 - accuracy: 0.9091 - val_loss: 0.3041 - val_accuracy: 0.8916
# Epoch 12/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2437 - accuracy: 0.9121 - val_loss: 0.2913 - val_accuracy: 0.8949
# Epoch 13/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2419 - accuracy: 0.9119 - val_loss: 0.2883 - val_accuracy: 0.8982
# Epoch 14/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2419 - accuracy: 0.9115 - val_loss: 0.2899 - val_accuracy: 0.8983
# Epoch 15/100
# 58/58 [==============================] - 6s 103ms/step - loss: 0.2366 - accuracy: 0.9126 - val_loss: 0.2877 - val_accuracy: 0.8993
# Epoch 16/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2337 - accuracy: 0.9148 - val_loss: 0.2916 - val_accuracy: 0.8974
# Epoch 17/100
# 58/58 [==============================] - 6s 103ms/step - loss: 0.2354 - accuracy: 0.9134 - val_loss: 0.2916 - val_accuracy: 0.8949
# Epoch 18/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2297 - accuracy: 0.9152 - val_loss: 0.2855 - val_accuracy: 0.8980
# Epoch 19/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2314 - accuracy: 0.9164 - val_loss: 0.2874 - val_accuracy: 0.8984
# Epoch 20/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2278 - accuracy: 0.9170 - val_loss: 0.2957 - val_accuracy: 0.8942
# Epoch 21/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2271 - accuracy: 0.9166 - val_loss: 0.2876 - val_accuracy: 0.8997
# Epoch 22/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2247 - accuracy: 0.9168 - val_loss: 0.2999 - val_accuracy: 0.8970
# Epoch 23/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2234 - accuracy: 0.9180 - val_loss: 0.2833 - val_accuracy: 0.9007
# Epoch 24/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2207 - accuracy: 0.9200 - val_loss: 0.2833 - val_accuracy: 0.8992
# Epoch 25/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2173 - accuracy: 0.9214 - val_loss: 0.2865 - val_accuracy: 0.8998
# Epoch 26/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2242 - accuracy: 0.9183 - val_loss: 0.2879 - val_accuracy: 0.8981
# Epoch 27/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2159 - accuracy: 0.9203 - val_loss: 0.2786 - val_accuracy: 0.9019
# Epoch 28/100
# 58/58 [==============================] - 6s 103ms/step - loss: 0.2130 - accuracy: 0.9214 - val_loss: 0.2806 - val_accuracy: 0.9016
# Epoch 29/100
# 58/58 [==============================] - 6s 107ms/step - loss: 0.2124 - accuracy: 0.9224 - val_loss: 0.2851 - val_accuracy: 0.8999
# Epoch 30/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2126 - accuracy: 0.9214 - val_loss: 0.2809 - val_accuracy: 0.9025
# Epoch 31/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2064 - accuracy: 0.9238 - val_loss: 0.2868 - val_accuracy: 0.9007
# Epoch 32/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2062 - accuracy: 0.9248 - val_loss: 0.2971 - val_accuracy: 0.8952
# Epoch 33/100
# 58/58 [==============================] - 6s 103ms/step - loss: 0.2107 - accuracy: 0.9214 - val_loss: 0.2790 - val_accuracy: 0.9020
# Epoch 34/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2061 - accuracy: 0.9233 - val_loss: 0.2851 - val_accuracy: 0.9013
# Epoch 35/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2041 - accuracy: 0.9247 - val_loss: 0.2870 - val_accuracy: 0.9024
# Epoch 36/100
# 58/58 [==============================] - 6s 105ms/step - loss: 0.2026 - accuracy: 0.9249 - val_loss: 0.2860 - val_accuracy: 0.9011
# Epoch 37/100
# 58/58 [==============================] - 6s 104ms/step - loss: 0.2015 - accuracy: 0.9254 - val_loss: 0.2815 - val_accuracy: 0.9017

# %% [markdown]
# Recompute the accuracy of your model, does it improve your performances with data augmentation?

# %%
# TODO: Compute the accuracy of your model
from sklearn.metrics import accuracy_score

batch_size=1024
y_pred_train = to_categorical(model.predict(X_train_norm, batch_size = batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm, batch_size = batch_size).argmax(axis=1), num_classes=10)

print('accuracy on train with NN:', accuracy_score(y_pred_train, y_train_cat))
print('accuracy on test with NN:', accuracy_score(y_pred_test, y_test_cat))
# Out:
# 59/59 [==============================] - 2s 34ms/step
# 10/10 [==============================] - 0s 32ms/step
# accuracy on train with NN: 0.93315
# accuracy on test with NN: 0.9017

# %% [markdown]
# You can now try to improve even more your results. For example, add more parameters to your `ImageDataGenerator`, play with some hyperparameters, and so on...
