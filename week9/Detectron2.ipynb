# %% [markdown]
# # Object detection with Detectron2

# %% [markdown]
# ![](https://cdn.ps.emap.com/wp-content/uploads/sites/3/2017/12/Oxford_Street.jpg)

# %% [markdown]
# ## 1) Install detectron2 (if running on Colab with GPU enabled)
#
# Check torch and cuda version then install the correponding pre-built detectron2: https://detectron2.readthedocs.io/en/latest/tutorials/install.html

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# Out:
# 2.6.0+cu126 True
# gcc (MinGW.org GCC-6.3.0-1) 6.3.0
# Copyright (C) 2016 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !python -m pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu111/torch1.10/index.html
# exit(0)  # After installation, you need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu111/torch1.10/index.html
# Requirement already satisfied: detectron2 in c:\users\denis\pycharmprojects\3803ict\detectron2 (0.6)
# Requirement already satisfied: Pillow>=7.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (3.10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (2.5.0)
# Requirement already satisfied: yacs>=0.1.8 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (0.1.8)
# Requirement already satisfied: tabulate in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (0.9.0)
# Requirement already satisfied: cloudpickle in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (3.1.1)
# Requirement already satisfied: tqdm>4.29.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (4.67.1)
# Requirement already satisfied: tensorboard in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (2.13.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (1.3.2)
# Requirement already satisfied: black in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (25.1.0)
# Requirement already satisfied: packaging in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from detectron2) (24.2)
# Requirement already satisfied: numpy in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (1.24.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from hydra-core>=1.1->detectron2) (4.9.3)
# Requirement already satisfied: portalocker in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from iopath<0.1.10,>=0.1.7->detectron2) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from matplotlib->detectron2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from matplotlib->detectron2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from matplotlib->detectron2) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from matplotlib->detectron2) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from matplotlib->detectron2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from matplotlib->detectron2) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tqdm>4.29.0->detectron2) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from black->detectron2) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from black->detectron2) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from black->detectron2) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from black->detectron2) (3.10.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from black->detectron2) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from black->detectron2) (4.13.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (2.2.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (1.71.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (3.7)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (2.32.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (72.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from tensorboard->detectron2) (0.45.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from python-dateutil>=2.7->matplotlib->detectron2) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from werkzeug>=1.0.1->tensorboard->detectron2) (2.1.5)
# Requirement already satisfied: pywin32>=226 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from portalocker->iopath<0.1.10,>=0.1.7->detectron2) (308)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\denis\anaconda3\envs\3803ict\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2) (3.2.2)

# %% [markdown]
# ## 2) Install detectron2 in local (if not using Colab)
#
# Install Detectron2 in Windows, Linux with Anaconda and GPU-enabled:
#
# https://medium.com/@yogeshkumarpilli/how-to-install-detectron2-on-windows-10-or-11-2021-aug-with-the-latest-build-v0-5-c7333909676f
#
# https://medium.com/@sujoydebnath.92/installing-detectron2-with-anaconda-and-cuda-on-linux-7b710663326c
#
# https://anaconda.org/conda-forge/detectron2
#
#
# Installing Detectron2 natively for Mac M1 Pro / Apple silicon (use Miniforge) (tested):
#
# https://medium.com/@hakon.hukkelas/installing-detectron2-natively-for-mac-m1-pro-apple-silicon-a89517f1c913

# %% [markdown]
# ## 3) Inference with pre-trained model

# %% [markdown]
# #### Import packages

# %%
# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# We first need to download a image to make predictions on.

# %%
# !wget https://cdn.ps.emap.com/wp-content/uploads/sites/3/2017/12/Oxford_Street.jpg -O oxford_street.jpg
import requests

image_url = "https://cdn.ps.emap.com/wp-content/uploads/sites/3/2017/12/Oxford_Street.jpg"
img_data = requests.get(image_url).content
with open('oxford_street.jpg', 'wb') as handler:
    handler.write(img_data)

import os
os.stat('oxford_street.jpg')
# Out:
# os.stat_result(st_mode=33206, st_ino=3659174697633827, st_dev=175243374, st_nlink=1, st_uid=0, st_gid=0, st_size=179209, st_atime=1743151873, st_mtime=1743151873, st_ctime=1742801144)

# %%
# %matplotlib inline
im = cv2.imread("./oxford_street.jpg")
plt.imshow(im)

from IPython.display import Image
Image(filename='oxford_street.jpg')

# %% [markdown]
# #### Import the model and the config
#
# Your turn to work now !

# %% [markdown]
# - for example, you can choose Faster_rcnn pretrained (its signature is `"COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml"` in the detectron model zoo)

# %%
# Create config
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml")
cfg.MODEL.DEVICE = 'cuda'

# %%
# Generate model and Create predictor
predictor = DefaultPredictor(cfg)
# Out:
# model_final_f6e8b1.pkl: 243MB [00:17, 14.1MB/s]

# %%
# Make prediction
outputs = predictor(im)
# Out:
# C:\Users\Denis\anaconda3\envs\3803ict\lib\site-packages\torch\functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:3638.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# Visualize the bounding boxes on the image
v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
plt.figure(figsize=(14, 10))
plt.imshow(cv2.cvtColor(v.get_image()[:, :, ::-1], cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# **\[BONUS\]** Feel free to :
# - Test the faster-RNN we just used on other images of your choosing
# - Test some of the other algorithms available in the [model zoo](https://github.com/facebookresearch/detectron2/blob/master/MODEL_ZOO.md) and see how they perform
